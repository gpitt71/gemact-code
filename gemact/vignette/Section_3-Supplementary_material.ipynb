# %% [markdown]
# # Supplementary material on Section 3
#
# **We remark that the execution of this script takes several hours, due to the computing time measurement which runs several experiments.**
#
# This code block allows to replicate replicate Section 3.6 Comparison of the methods for computing the aggregate loss distribution and Section 3.7. Comparison with aggregate FFT implementation [manuscript](https://arxiv.org/abs/2303.01129) describing the usage and the design of the GEMAct package.
#
# This vignette is relative to the version 1.2.1 of the GEMAct software.
#
# We compared our computation with the version 0.9.3 of the software aggregate.

# %%
pip install gemact==1.2.1
# Out:
# Collecting gemact==1.2.1
#   Using cached gemact-1.2.1-py3-none-any.whl
# Requirement already satisfied: twiggy in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from gemact==1.2.1) (0.5.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from gemact==1.2.1) (2.5.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from gemact==1.2.1) (3.11.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from gemact==1.2.1) (1.18.0)
# Requirement already satisfied: setuptools>=65.5.1 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from gemact==1.2.1) (83.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib>=3.5.0->gemact==1.2.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->gemact==1.2.1) (1.17.0)
# Installing collected packages: gemact
# Successfully installed gemact-1.2.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
pip install aggregate==0.9.3
# Out:
# Collecting aggregate==0.9.3
#   Downloading aggregate-0.9.3.tar.gz (137 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pypandoc (from aggregate==0.9.3)
#   Downloading pypandoc-1.17-py3-none-any.whl.metadata (18 kB)
# Collecting sly==0.3 (from aggregate==0.9.3)
#   Downloading sly-0.3.tar.gz (49 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from aggregate==0.9.3) (1.18.0)
# Collecting seaborn (from aggregate==0.9.3)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from aggregate==0.9.3) (3.11.1)
# Requirement already satisfied: numpy in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from aggregate==0.9.3) (2.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from matplotlib->aggregate==0.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->aggregate==0.9.3) (1.17.0)
# Collecting pandas>=1.2 (from seaborn->aggregate==0.9.3)
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting tzdata (from pandas>=1.2->seaborn->aggregate==0.9.3)
#   Downloading tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pypandoc-1.17-py3-none-any.whl (23 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/10.0 MB 8.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/10.0 MB 7.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/10.0 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/10.0 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.0 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 8.4 MB/s  0:00:01
# Downloading tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Building wheels for collected packages: aggregate, sly
#   Building wheel for aggregate (pyproject.toml): started
#   Building wheel for aggregate (pyproject.toml): finished with status 'done'
#   Created wheel for aggregate: filename=aggregate-0.9.3-py3-none-any.whl size=138110 sha256=432afce366c6e432e5b187d9827fb8500327fb9a38c0f33ce6c57e4e73fcd7ff
#   Stored in directory: c:\users\pwt887\appdata\local\pip\cache\wheels\47\ff\42\d9ce9bbb6edde929fde7cf3794f0b64f659bee7f63cdacbcb5
#   Building wheel for sly (pyproject.toml): started
#   Building wheel for sly (pyproject.toml): finished with status 'done'
#   Created wheel for sly: filename=sly-0.3-py3-none-any.whl size=24606 sha256=8ceedc5a0343192df5e7885a1612ef689baec9c46c8b32c9934f6cc297885b03
#   Stored in directory: c:\users\pwt887\appdata\local\pip\cache\wheels\cb\db\cc\073fe4fc056ad2504308bd04918bd1834f195d0b9e9c38a334
# Successfully built aggregate sly
# Installing collected packages: sly, tzdata, pypandoc, pandas, seaborn, aggregate
#
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------------- -------------------------- 2/6 [pypandoc]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------- ------------------- 3/6 [pandas]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    -------------------------- ------------- 4/6 [seaborn]
#    --------------------------------- ------ 5/6 [aggregate]
#    ---------------------------------------- 6/6 [aggregate]
#
# Successfully installed aggregate-0.9.3 pandas-3.0.5 pypandoc-1.17 seaborn-0.13.2 sly-0.3 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from gemact.lossmodel import Severity, Frequency, LossModel, PolicyStructure, Layer
from gemact.calculators import LossModelCalculator as Calculator
import numpy as np
import pandas as pd
import timeit as timeit
from aggregate import build, qd

# script parameters
# local path to save
localpath = ''
explort_flag = True

# severity parameters
mu = 84541.68  # target mean lognorm
sigma = 177728.3  # target std lognorm

a = 1 + (sigma / mu) ** 2
shape = np.sqrt(np.log(a))
scale = mu / np.sqrt(a)

sev_par = {'scale': scale, 'shape':shape}
sev_dist_name = 'lognormal'
freq_par = {'mu': 3}
freq_dist_name = 'poisson'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 6
#       2 from gemact.calculators import LossModelCalculator as Calculator
#       3 import numpy as np
#       4 import pandas as pd
#       5 import timeit as timeit
# ----> 6 from aggregate import build, qd
#       7
#       8 # script parameters
#       9 # local path to save
#
# File c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages\aggregate\__init__.py:12
#       9 __status__ = "alpha"
#      11 # imports
# ---> 12 from .underwriter import Underwriter, build
#      13 from .port import Portfolio
#      14 from .distr import Frequency, Severity, Aggregate, CarefulInverse
#
# File c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages\aggregate\underwriter.py:104
#     102 import os
#     103 import numpy as np
# --> 104 from IPython.core.display import display
#     105 import logging
#     106 import pandas as pd
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (c:\Users\pwt887\Documents\github\gemact-code\.venv\Lib\site-packages\IPython\core\display.py)

# %% [markdown]
# ## Section 3.6 Comparison of the methods for computing the aggregate loss distribution
#
# The parametric assumptions are taken from examples in Parodi, P. (2014). Pricing in general insurance (first ed.), pag. 262-266

# %%
# timeit parameters. Number of repetitions for computation time.
repetitions = 7 # numer of times the experiment is repeated
number = 100 # number of times the function is executed in a experiment.

# policystructure parmateres
deductible = 10000
cover = float('inf')

n_sev_nodes = [2**14, 2**16, 2**18]
n_sev_nodes_str = ['2**14', '2**16', '2**18']
n_aggr_nodes =  [2**14, 2**16, 2**18]
discr_step = [50, 100, 200, 400]
n_sim_mc = [2**14, 2**16, 2**18, 2**20]
n_sim_mc_str = ['2**14', '2**16', '2**18', '2**20'] 

discr_methods = ['massdispersal']
calculation_methods = [
    'fast_fourier_transform',
    'panjer_recursion'
]
calculation_methods_abbr = ['fft', 'recursion']

outputtxt = []

sev = Severity(par=sev_par, dist=sev_dist_name)
freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=deductible)
pstr = PolicyStructure(layers=Layer(deductible=deductible, cover=cover))

calc_true_values_flag = True
for j in range(len(calculation_methods)):
    for i in range(len(n_sev_nodes)):
        print('n_sev_nodes:' + str(n_sev_nodes[i]))
        for k in range(len(discr_step)):

            print('discr_step:' + str(discr_step[k]))
            sevdict = sev.discretize(
            discr_method=discr_methods[0],
            n_discr_nodes=n_sev_nodes[i],
            discr_step=discr_step[k],
            deductible=deductible)

            lm = LossModel(
                severity=sev,
                frequency=freq,
                policystructure=pstr,
                aggr_loss_dist_method=calculation_methods_abbr[j],
                n_aggr_dist_nodes=n_aggr_nodes[i],
                n_sev_discr_nodes=n_sev_nodes[i],
                sev_discr_step=discr_step[k],
                sev_discr_method=discr_methods[0],
                tilt=True
                )
            
            if calc_true_values_flag:
                txt = [
                    'True Value & &',
                    "{:.1f}".format(lm.mean(use_dist=False)),
                    '& ', "{:.5f}".format(lm.coeff_variation(use_dist=False)),
                    '& ', "{:.5f}".format(lm.skewness(use_dist=False)),
                    '\\\\'
                    ]
                outputtxt.append(' '.join(txt))
                calc_true_values_flag = False

            vals = [
                lm.mean(use_dist=True) / lm.mean(use_dist=False) - 1,
                lm.coeff_variation(use_dist=True) / lm.coeff_variation(use_dist=False) - 1,
                lm.skewness(use_dist=True) / lm.skewness(use_dist=False) - 1
            ]
            txt = ["{:.5e}".format(x) for x in vals]
            
            if calculation_methods[j] == 'fast_fourier_transform':
                stmt = "Calculator." + calculation_methods[j]+"(" \
                    "frequency=freq," \
                    "severity=sevdict," \
                    "discr_step=" + str(discr_step[k]) +"," \
                    "tilt=True," \
                    "tilt_value=20/"+ str(n_aggr_nodes[i]) +"," \
                    "n_aggr_dist_nodes=" + str(n_aggr_nodes[i]) + "" \
                    ")"
            else:
                stmt = "Calculator." + calculation_methods[j]+"(" \
                    "frequency=freq," \
                    "severity=sevdict," \
                    "discr_step=" + str(discr_step[k]) +"," \
                    "n_aggr_dist_nodes=" + str(n_aggr_nodes[i]) + "" \
                    ")"
            out = timeit.repeat(stmt,
                        repeat=repetitions,
                        number=number,
                        globals=locals())
            txt.insert(0, str(round(np.min(out) / number, 5)))
            txt.insert(0, str(calculation_methods_abbr[j]) +' (h = ' + str(discr_step[k]) + ', m = '+ str(n_sev_nodes_str[i]) + ')')
            outputtxt.append('& '.join(txt) + '\\\\')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 25
#      21 calculation_methods_abbr = ['fft', 'recursion']
#      22
#      23 outputtxt = []
#      24
# ---> 25 sev = Severity(par=sev_par, dist=sev_dist_name)
#      26 freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=deductible)
#      27 pstr = PolicyStructure(layers=Layer(deductible=deductible, cover=cover))
#      28
#
# NameError: name 'sev_par' is not defined

# %%
calc_true_values_flag = False
random_state = 11
for k in range(len(n_sim_mc)):
    lm = LossModel(
        severity=sev,
        frequency=freq,
        policystructure=pstr,
        aggr_loss_dist_method='mc',
        n_sim=n_sim_mc[k],
        random_state=random_state
        )
    if calc_true_values_flag:
        txt = [
            'True Value & &',
            "{:.1f}".format(lm.mean(use_dist=False)),
            '& ', "{:.5f}".format(lm.coeff_variation(use_dist=False)),
            '& ', "{:.5f}".format(lm.skewness(use_dist=False)),
            '\\\\'
            ]
        outputtxt.append(' '.join(txt))
        calc_true_values_flag = False
    
    vals = [
        lm.mean(use_dist=True) / lm.mean(use_dist=False) - 1,
        lm.coeff_variation(use_dist=True) / lm.coeff_variation(use_dist=False) - 1,
        lm.skewness(use_dist=True) / lm.skewness(use_dist=False) - 1
        ]
    txt = ["{:.5e}".format(x) for x in vals]

    stmt = "Calculator.mc_simulation(" \
               "severity=sev," \
               "frequency=freq," \
               "n_sim=" + str(n_sim_mc[k]) + "," \
               "random_state=" + str(random_state) + "," \
               "cover=float('inf')," \
               "deductible=" + str(deductible) + "," \
               ")"
    out = timeit.repeat(stmt,
                repeat=repetitions,
                number=number,
                globals=locals())
    txt.insert(0, str(round(np.min(out) / number, 4)))
    txt.insert(0, 'MC (' + str(n_sim_mc_str[k]) + ' sim.)')
    outputtxt.append('& '.join(txt) + '\\\\')


# export results
if explort_flag:
    pd.DataFrame(data = outputtxt, columns=['text']).to_csv(localpath + 'aggr_dist_method_comparison.txt', index=False)
    print('finish')

# %% [markdown]
# ## Section 3.7. Comparison with aggregate FFT implementation
#
# The parametric assumptions and contract specifications taken from examples in Parodi, P. (2014). Pricing in general insurance (first ed.), pag. 262-266.

# %%
sev = Severity(par=sev_par, dist=sev_dist_name)
# frequency and policystructure specified below.
outputtxt = []

n_nodes = 2**22
power_nodes = int(np.log2(n_nodes))
discr_step = 500
deductible = 10000
cover = 1000000
aggr_cover = 1000000
aggr_deductible = 50000

# %% [markdown]
# ### No individual, no aggregate conditions
#
# deductible = 0, cover = inf, aggr. cover = inf, aggr. deductible = 0,

# %%
agg_nr = build(
    'agg noreins 3 claims sev lognorm 84541.68 cv 2.1022565437545127 poisson',
    log2=power_nodes,
    padding=0,
    bs=discr_step
    )

stmt = "build('agg noreins 3 claims sev lognorm 84541.68 cv 2.1022565437545127 poisson'," \
            "log2=" +str(power_nodes) + "," \
            "padding=0," \
            "bs=" + str(discr_step)  + "," \
            ")"
outagg = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=0)
pstr = PolicyStructure()
lm = LossModel(
    frequency=freq,
    severity=sev,
    policystructure=pstr,
    aggr_loss_dist_method='fft',
    n_aggr_dist_nodes=n_nodes,
    sev_discr_step=discr_step,
    sev_discr_method='massdispersal'
)
stmt = "LossModel("\
    "frequency=freq,"\
    "severity=sev,"\
    "policystructure=pstr,"\
    "aggr_loss_dist_method='fft',"\
    "n_aggr_dist_nodes=" + str(n_nodes) + "," \
    "sev_discr_step="+ str(discr_step) + "," \
    "sev_discr_method='massdispersal'"\
    ")"
outgem = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

txt = [
    ' & Reference Value & &',
    "{:.1f}".format(lm.mean(use_dist=False)),
    '& ', "{:.5f}".format(lm.coeff_variation(use_dist=False)),
    '& ', "{:.5f}".format(lm.skewness(use_dist=False)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

txt = [
    ' & gemact &',
    str(round(np.min(outgem) / number, 4)) + '& ',
    "{:.1f}".format(lm.mean(use_dist=True)),
    '& ', "{:.5f}".format(lm.coeff_variation(use_dist=True)),
    '& ', "{:.5f}".format(lm.skewness(use_dist=True)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

txt = [
    ' & aggregate &',
    str(round(np.min(outagg) / number, 4)) + '& ',
    "{:.1f}".format(agg_nr.est_m),
    '& ', "{:.5f}".format(agg_nr.est_cv),
    '& ', "{:.5f}".format(agg_nr.est_skew),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

# %% [markdown]
# ### XL no aggregate conditions
#
# deductible = 10000, cover = 1000000, aggr. deductible = 0, aggr. cover = inf

# %%
agg_xl = build(
    'agg noreins 3 claims 1000000 xs 10000 sev lognorm 84541.68 cv 2.1022565437545127 poisson',
    log2=power_nodes,
    padding=0,
    bs=discr_step
    )
agg_xl.describe

stmt = "build('agg noreins 3 claims 1000000 xs 10000 sev lognorm 84541.68 cv 2.1022565437545127 poisson'," \
            "log2=" +str(power_nodes) + "," \
            "padding=0," \
            "bs=" + str(discr_step)  + "," \
            ")"
outagg = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

pstr = PolicyStructure(
    layers=Layer(
        deductible=deductible,
        cover=cover
    )
)

freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=deductible)
lm_xl = LossModel(
    frequency=freq,
    severity=sev,
    policystructure=pstr,
    aggr_loss_dist_method='fft',
    n_aggr_dist_nodes=n_nodes,
    sev_discr_method='massdispersal'
)

stmt = "LossModel("\
    "frequency=freq,"\
    "severity=sev,"\
    "policystructure=pstr,"\
    "aggr_loss_dist_method='fft',"\
    "n_aggr_dist_nodes=" + str(n_nodes) + "," \
    "sev_discr_method='massdispersal'"\
    ")"
outgem = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())
txt = [
    ' & Reference Value & &',
    "{:.1f}".format(lm_xl.mean(use_dist=False)),
    '& ', "{:.5f}".format(lm_xl.coeff_variation(use_dist=False)),
    '& ', "{:.5f}".format(lm_xl.skewness(use_dist=False)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

txt = [
    ' & gemact &',
    str(round(np.min(outgem) / number, 4)) + '& ',
    "{:.1f}".format(lm_xl.mean(use_dist=True)),
    '& ', "{:.5f}".format(lm_xl.coeff_variation(use_dist=True)),
    '& ', "{:.5f}".format(lm_xl.skewness(use_dist=True)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))


txt = [
    ' & aggregate &',
    str(round(np.min(outagg) / number, 4)) + '& ',
    "{:.1f}".format(agg_xl.est_m),
    '& ', "{:.5f}".format(agg_xl.est_cv),
    '& ', "{:.5f}".format(agg_xl.est_skew),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

# %% [markdown]
# ### XL aggregate conditions only, i.e. SL
#
# deductible = 0, cover = inf, aggr. deductible = 50000, aggr. cover = 1000000

# %%
agg_sl = build(
    'agg experiment 3 claims sev lognorm 84541.68 cv 2.1022565437545127 poisson aggregate ceded to 1000000 xs 50000',
    log2=power_nodes,
    padding=0,
    bs=discr_step
    )
agg_sl.describe

stmt = "build('agg experiment 3 claims sev lognorm 84541.68 cv 2.1022565437545127 poisson aggregate ceded to 1000000 xs 50000'," \
            "log2=" +str(power_nodes) + "," \
            "padding=0," \
            "bs=" + str(discr_step)  + "," \
            ")"
outagg = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=0)
pstr = PolicyStructure(
    layers=Layer(
        deductible = 0,
        cover = float('inf'),
        aggr_deductible = aggr_deductible,
        aggr_cover = aggr_cover
    )
)

lm_sl = LossModel(
    frequency=freq,
    severity=sev,
    policystructure=pstr,
    aggr_loss_dist_method='fft',
    n_aggr_dist_nodes=n_nodes,
    sev_discr_step=discr_step,
    sev_discr_method='massdispersal'
)

stmt = "LossModel("\
    "frequency=freq,"\
    "severity=sev,"\
    "policystructure=pstr,"\
    "aggr_loss_dist_method='fft',"\
    "n_aggr_dist_nodes=" + str(n_nodes) + "," \
    "sev_discr_step="+ str(discr_step) + "," \
    "sev_discr_method='massdispersal'"\
    ")"
outgem = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

txt = [' & Reference Value & - & - & -\\\\']
outputtxt.append(' '.join(txt))

txt = [
    ' & gemact &',
    str(round(np.min(outgem) / number, 4)) + '& ',
    "{:.1f}".format(lm_sl.mean(use_dist=True)),
    '& ', "{:.5f}".format(lm_sl.coeff_variation(use_dist=True)),
    '& ', "{:.5f}".format(lm_sl.skewness(use_dist=True)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

txt = [
    ' & aggregate &',
    str(round(np.min(outagg) / number, 4)) + '& ',
    "{:.1f}".format(agg_sl.est_m),
    '& ', "{:.5f}".format(agg_sl.est_cv),
    '& ', "{:.5f}".format(agg_sl.est_skew),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

# %% [markdown]
# ### XL with aggregate conditions (XL + SL)
#
# deductible = 10000, cover = 1000000, aggr. deductible = 50000, aggr. cover = 1000000

# %%
agg_xlsl = build('agg experiment 3 claims 1000000 xs 10000 sev lognorm 84541.68 cv 2.1022565437545127 poisson aggregate ceded to 1000000 xs 50000',
        log2=power_nodes,
        padding=0,
        bs=discr_step)
agg_xlsl.describe

stmt = "build('agg experiment 3 claims 1000000 xs 10000 sev lognorm 84541.68 cv 2.1022565437545127 poisson aggregate ceded to 1000000 xs 50000'," \
            "log2=" +str(power_nodes) + "," \
            "padding=0," \
            "bs=" + str(discr_step)  + "," \
            ")"
outagg = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

pstr = PolicyStructure(
    layers=Layer(
        deductible = deductible,
        cover = cover,
        aggr_deductible = aggr_deductible,
        aggr_cover = aggr_cover
    )
)
freq = Frequency(dist=freq_dist_name, par=freq_par, threshold=deductible)
lm_xlsl = LossModel(
    frequency=freq,
    severity=sev,
    policystructure=pstr,
    aggr_loss_dist_method='fft',
    n_aggr_dist_nodes=n_nodes,
    sev_discr_method='massdispersal'
)

stmt = "LossModel("\
    "frequency=freq,"\
    "severity=sev,"\
    "policystructure=pstr,"\
    "aggr_loss_dist_method='fft',"\
    "n_aggr_dist_nodes=" + str(n_nodes) + "," \
    "sev_discr_method='massdispersal'"\
    ")"
outgem = timeit.repeat(stmt,
            repeat=repetitions,
            number=number,
            globals=locals())

txt = [' & Reference Value & - & - & -\\\\']
outputtxt.append(' '.join(txt))

txt = [
    ' & gemact &',
    str(round(np.min(outgem) / number, 4)) + '& ',
    "{:.1f}".format(lm_xlsl.mean(use_dist=True)),
    '& ', "{:.5f}".format(lm_xlsl.coeff_variation(use_dist=True)),
    '& ', "{:.5f}".format(lm_xlsl.skewness(use_dist=True)),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

txt = [
    ' & aggregate &',
    str(round(np.min(outagg) / number, 4)) + '& ',
    "{:.1f}".format(agg_xlsl.est_m),
    '& ', "{:.5f}".format(agg_xlsl.est_cv),
    '& ', "{:.5f}".format(agg_xlsl.est_skew),
    '\\\\'
    ]
outputtxt.append(' '.join(txt))

# export results
if explort_flag:
    pd.DataFrame(data = outputtxt, columns=['text']).to_csv(localpath + 'aggregate_comparison.txt', index=False)
